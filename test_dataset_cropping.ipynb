# %%
import os, os.path 
import cv2,sys
import glob

# %%
path='C:/Users/gptjd/Downloads/image-20200904T130849Z-001/image'

for i in os.listdir(path):
    num=0
    num=num+1
    img=cv2.imread(path+"/"+i)
    img_trim=img[384:1024,:]
    cv2.imwrite(os.path.join("C:/Users/gptjd/OneDrive/Desktop/save",i),img_trim)
    print(img_trim.shape)
    print(num)
# Out:
# (640, 1280, 3)
# 1
# (640, 1280, 3)
# 1
# (640, 1280, 3)
# 1
# (640, 1280, 3)
# 1
# (640, 1280, 3)
# 1
# (640, 1280, 3)
# 1
# (640, 1280, 3)
# 1
# (640, 1280, 3)
# 1
# (640, 1280, 3)
# 1
# (640, 1280, 3)
# 1
# (640, 1280, 3)
# 1
# (640, 1280, 3)
# 1
# (640, 1280, 3)
# 1
# (640, 1280, 3)
# 1
# (640, 1280, 3)
# 1
# (640, 1280, 3)
# 1
# (640, 1280, 3)
# 1
# (640, 1280, 3)
# 1
# (640, 1280, 3)
# 1
# (640, 1280, 3)
# 1
# (640, 1280, 3)
# 1
# (640, 1280, 3)
# 1
# (640, 1280, 3)
# 1
# (640, 1280, 3)
# 1
# (640, 1280, 3)
# 1
# (640, 1280, 3)
# 1
# (640, 1280, 3)
# 1
# (640, 1280, 3)
# 1
# (640, 1280, 3)
# 1
# (640, 1280, 3)
# 1
# (640, 1280, 3)
# 1
# (640, 1280, 3)
# 1
# (640, 1280, 3)
# 1
# (640, 1280, 3)
# 1
# (640, 1280, 3)
# 1
# (640, 1280, 3)
# 1
# (640, 1280, 3)
# 1
# (640, 1280, 3)
# 1
# (640, 1280, 3)
# 1
# (640, 1280, 3)
# 1
# (640, 1280, 3)
# 1
# (640, 1280, 3)
# 1
# (640, 1280, 3)
# 1
# (640, 1280, 3)
# 1
# (640, 1280, 3)
# 1
# (640, 1280, 3)
# 1
# (640, 1280, 3)
# 1
# ...
